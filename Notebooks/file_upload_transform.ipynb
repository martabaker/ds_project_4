# %%
# Dependencies
import pandas as pd

# %%
# Import Files
test_df = pd.read_csv("../Resources/test.csv", encoding="UTF-8")
train_df = pd.read_csv("../Resources/train.csv", encoding="UTF-8")

display(test_df.head())
train_df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %% [markdown]
# ### Data Cleaning

# %%
# Fix column names
test_df.columns = [x.lower().replace(" ", "_") for x in test_df.columns]
train_df.columns = [x.lower().replace(" ", "_") for x in train_df.columns]

test_df.rename(columns={"class": "travel_class"}, inplace=True)
train_df.rename(columns={"class": "travel_class"}, inplace=True)

# %%
# Determine datatypes and check for nulls
display(test_df.info())
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   unnamed:_0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   gender                             25976 non-null  object
#  3   customer_type                      25976 non-null  object
#  4   age                                25976 non-null  int64
#  5   type_of_travel                     25976 non-null  object
#  6   travel_class                       25976 non-null  object
#  7   flight_distance                    25976 non-null  int64
#  8   inflight_wifi_service              25976 non-null  int64
#  9   departure/arrival_time_convenient  25976 non-null  int64
#  10  ease_of_online_booking             25976 non-null  int64
# ...

# %% [markdown]
# Note: There appear to be some nulls in `arrival_delay_in_minutes` for both tables

# %%
# Check percentage of nulls for each dataset
print(f"test nulls: {(25976-25893)/25976} \ntrain nulls: {(103904-103594)/103904}")
# Out:
# test nulls: 0.0031952571604558053
# train nulls: 0.00298352325223283

# %%
# Given how few nulls there are, going to just drop those rows
test_df = test_df.dropna(how="any").reset_index(drop=True)
train_df = train_df.dropna(how="any").reset_index(drop=True)

display(test_df.head())
train_df.head()
# Out:
#    unnamed:_0     id  gender      customer_type  age   type_of_travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#   travel_class  flight_distance  inflight_wifi_service  \
# 0          Eco              160                      5
# 1     Business             2863                      1
# 2          Eco              192                      2
# 3     Business             3377                      0
# 4          Eco             1182                      2
#
#    departure/arrival_time_convenient  ...  inflight_entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %% [markdown]
# Drop the `unnamed:_0` column because it's another index column and as such is redundant

# %%
test_df.drop(columns=test_df.columns[0], axis=1, inplace=True)
train_df.drop(columns=train_df.columns[0], axis=1, inplace=True)

# %% [markdown]
# ### Combine both tables to create a complete table

# %%
combined_df = pd.concat([test_df, train_df])
display(combined_df.shape)
display(combined_df.head())
combined_df.info()
# Out:
# (129487, 24)
#       id  gender      customer_type  age   type_of_travel travel_class  \
# 0  19556  Female     Loyal Customer   52  Business travel          Eco
# 1  90035  Female     Loyal Customer   36  Business travel     Business
# 2  12360    Male  disloyal Customer   20  Business travel          Eco
# 3  77959    Male     Loyal Customer   44  Business travel     Business
# 4  36875  Female     Loyal Customer   49  Business travel          Eco
#
#    flight_distance  inflight_wifi_service  departure/arrival_time_convenient  \
# 0              160                      5                                  4
# 1             2863                      1                                  1
# 2              192                      2                                  0
# 3             3377                      0                                  0
# 4             1182                      2                                  3
#
# ...

# %% [markdown]
# ### Save Off Tables

# %%
test_df.to_csv("../Resources/test_cleaned.csv", index=False)
train_df.to_csv("../Resources/train_cleaned.csv", index=False)
combined_df.to_csv("../Resources/combined_cleaned.csv", index=False)
